# %% [markdown]
# ## Create DataFrames and Prepare Data

# %%
import pandas as pd
import numpy as np


df_regions = pd.read_csv("../data/noc_regions.csv")
df_regions.head()

df = pd.read_csv("../data/athlete_events.csv")
df.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# 2           Football Men's Football   NaN
# 3       Tug-Of-War Men's Tug-Of-War  Gold
# 4  Speed Skating Women's 500 metres   NaN

# %%
df_group = df.groupby("Sport")
df_group.head(15)

# %%
from functions import bivariate

bivariate(df.head(15), 'Sport')

# %%
from optimizedfunction import optimized_bivariate

optimized_bivariate(df, "Sport")
# Out:
# Error processing feature ID: x and y must have length at least 2.
# Error processing feature Sex: x and y must have length at least 2.
# Error processing feature Name: x and y must have length at least 2.
# Error processing feature Age: x and y must have length at least 2.
# Error processing feature Team: x and y must have length at least 2.
# Error processing feature Height: x and y must have length at least 2.
# Error processing feature Weight: x and y must have length at least 2.
# Error processing feature Year: x and y must have length at least 2.
# Error processing feature NOC: x and y must have length at least 2.
# Error processing feature Medal: x and y must have length at least 2.
# Error processing feature Event: x and y must have length at least 2.
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[7], line 3
#       1 from optimizedfunction import optimized_bivariate
# ----> 3 optimized_bivariate(df, "Sport")
#
# File c:\Users\tyler\OneDrive - Brigham Young University\Documents\IS 455\CaseCompetition\Notebooks\optimizedfunction.py:89, in optimized_bivariate(df, label, roundto)
#      84     futures = [
#      85         executor.submit(process_feature, feature, df, label, roundto)
#      86         for feature in features
#      87     ]
#      88     for future in futures:
# ---> 89         results_list.append(future.result())
#      91 # Convert the list of dictionaries to a DataFrame
#      92 output_df = pd.DataFrame(results_list)
#
# File c:\Users\tyler\AppData\Local\Programs\Python\Python311\Lib\concurrent\futures\_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File c:\Users\tyler\AppData\Local\Programs\Python\Python311\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File c:\Users\tyler\AppData\Local\Programs\Python\Python311\Lib\concurrent\futures\thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# File c:\Users\tyler\OneDrive - Brigham Young University\Documents\IS 455\CaseCompetition\Notebooks\optimizedfunction.py:12, in optimized_bivariate.<locals>.process_feature(feature, df, label, roundto)
#       9 def process_feature(feature, original_df, label, roundto):
#      10     # Work with copies to avoid altering the original DataFrame
#      11     feature_data = pd.to_numeric(original_df[feature], errors="coerce").dropna()
# ---> 12     label_data = pd.to_numeric(original_df[label], errors="coerce").dropna()
#      14     # Ensure we're only working with rows where both feature and label data are present
#      15     common_index = feature_data.index.intersection(label_data.index)
#
# File c:\Users\tyler\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:3872, in DataFrame.__getitem__(self, key)
#    3865 # GH#45316 Return view if key is not duplicated
#    3866 # Only use drop_duplicates with duplicates for performance
#    3867 if not is_mi and (
#    3868     self.columns.is_unique
#    3869     and key in self.columns
#    3870     or key in self.columns.drop_duplicates(keep=False)
#    3871 ):
# -> 3872     return self._get_item_cache(key)
#    3874 elif is_mi and self.columns.is_unique and key in self.columns:
#    3875     return self._getitem_multilevel(key)
#
# File c:\Users\tyler\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:4418, in DataFrame._get_item_cache(self, item)
#    4413 if res is None:
#    4414     # All places that call _get_item_cache have unique columns,
#    4415     #  pending resolution of GH#33047
#    4417     loc = self.columns.get_loc(item)
# -> 4418     res = self._ixs(loc, axis=1)
#    4420     cache[item] = res
#    4422     # for a chain
#
# File c:\Users\tyler\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:3806, in DataFrame._ixs(self, i, axis)
#    3802 # icol
#    3803 else:
#    3804     label = self.columns[i]
# -> 3806     col_mgr = self._mgr.iget(i)
#    3807     result = self._box_col_values(col_mgr, i)
#    3809     # this is a cached value, mark it so
#
# File c:\Users\tyler\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\managers.py:996, in BlockManager.iget(self, i, track_ref)
#     992 """
#     993 Return the data as a SingleBlockManager.
#     994 """
#     995 block = self.blocks[self.blknos[i]]
# --> 996 values = block.iget(self.blklocs[i])
#     998 # shortcut for select a single-dim from a 2-dim BM
#     999 bp = BlockPlacement(slice(0, len(values)))
#
# File c:\Users\tyler\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\blocks.py:1014, in Block.iget(self, i)
#    1007 def iget(self, i: int | tuple[int, int] | tuple[slice, int]) -> np.ndarray:
#    1008     # In the case where we have a tuple[slice, int], the slice will always
#    1009     #  be slice(None)
#    (...)
#    1012     # for "Union[ndarray[Any, Any], ExtensionArray]"; expected type
#    1013     # "Union[int, integer[Any]]"
# -> 1014     return self.values[i]
#
# IndexError: index 1 is out of bounds for axis 0 with size 1
