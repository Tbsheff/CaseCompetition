# %% [markdown]
# ## Create DataFrames and Prepare Data

# %%
import pandas as pd
import numpy as np


df_regions = pd.read_csv("../data/noc_regions.csv")
df_regions.head()

df = pd.read_csv("../data/athlete_events.csv")
df.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# 2           Football Men's Football   NaN
# 3       Tug-Of-War Men's Tug-Of-War  Gold
# 4  Speed Skating Women's 500 metres   NaN

# %%
df_group = df.groupby("Sport")
df_group.head()
# Out:
#             ID                           Name Sex   Age  Height  Weight  \
# 0            1                      A Dijiang   M  24.0   180.0    80.0
# 1            2                       A Lamusi   M  23.0   170.0    60.0
# 2            3            Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4           Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5       Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                            ...  ..   ...     ...     ...
# 144851   72692  Neville Stephen Bulwer-Lytton   M  29.0     NaN     NaN
# 158944   79794         Eustace Hamilton Miles   M  39.0     NaN     NaN
# 214105  107506              Hermann Schreiber   M  26.0     NaN     NaN
# 230588  115733              Smith O. Streeter   M  59.0     NaN     NaN
# 252988  126675   Francisco Villota y Baquiola   M  26.0     NaN     NaN
#
#                   Team  NOC        Games  Year  Season       City  \
# 0                China  CHN  1992 Summer  1992  Summer  Barcelona
# 1                China  CHN  2012 Summer  2012  Summer     London
# 2              Denmark  DEN  1920 Summer  1920  Summer  Antwerpen
# 3       Denmark/Sweden  DEN  1900 Summer  1900  Summer      Paris
# 4          Netherlands  NED  1988 Winter  1988  Winter    Calgary
# ...                ...  ...          ...   ...     ...        ...
# 144851   Great Britain  GBR  1908 Summer  1908  Summer     London
# 158944   Great Britain  GBR  1908 Summer  1908  Summer     London
# 214105     Switzerland  SUI  1936 Summer  1936  Summer     Berlin
# 230588   United States  USA  1904 Summer  1904  Summer  St. Louis
# 252988           Spain  ESP  1900 Summer  1900  Summer      Paris
#
#                 Sport                                         Event   Medal
# 0          Basketball                   Basketball Men's Basketball     NaN
# 1                Judo                  Judo Men's Extra-Lightweight     NaN
# 2            Football                       Football Men's Football     NaN
# 3          Tug-Of-War                   Tug-Of-War Men's Tug-Of-War    Gold
# 4       Speed Skating              Speed Skating Women's 500 metres     NaN
# ...               ...                                           ...     ...
# 144851   Jeu De Paume                    Jeu De Paume Men's Singles  Bronze
# 158944   Jeu De Paume                    Jeu De Paume Men's Singles  Silver
# 214105    Aeronautics                 Aeronautics Mixed Aeronautics    Gold
# 230588          Roque                           Roque Men's Singles  Silver
# 252988  Basque Pelota  Basque Pelota Men's Two-Man Teams With Cesta    Gold
#
# [322 rows x 15 columns]

# %%
from functions import bivariate

bivariate(df, 'Sport')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 3
#       1 from functions import bivariate
# ----> 3 bivariate(df, 'Sport')
#
# File c:\Users\brend\OneDrive - Brigham Young University\Documents\BYU\Winter 2024\CaseCompetition\Notebooks\functions.py:151, in bivariate(df, label, roundto)
#     149     X2, p, dof, expected = stats.chi2_contingency(contingency_table)
#     150     output_df.loc[feature] = [f'{missing}%', '-', dtype, unique, p, '-', '-', '-', '-', '-', X2]
# --> 151     crosstab(df_temp, feature, label)
#     152 else:
#     153     # Process C2N and N2C relationships
#     154     if pd.api.types.is_numeric_dtype(df_temp[feature]):
#
# File c:\Users\brend\OneDrive - Brigham Young University\Documents\BYU\Winter 2024\CaseCompetition\Notebooks\functions.py:120, in crosstab(df, feature, label, roundto)
#     117 plt.text(.95, 0.2, textstr, fontsize=12, transform=plt.gcf().transFigure)
#     119 ct_df = pd.DataFrame(np.rint(contingency_table).astype('int64'), columns=crosstab.columns, index=crosstab.index)
# --> 120 sns.heatmap(ct_df, annot=True, fmt='d', cmap='coolwarm')
#     121 plt.show()
#
# File c:\Users\brend\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\matrix.py:459, in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     457 if square:
#     458     ax.set_aspect("equal")
# --> 459 plotter.plot(ax, cbar_ax, kwargs)
#     460 return ax
#
# File c:\Users\brend\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\matrix.py:352, in _HeatMapper.plot(self, ax, cax, kws)
#     350 # Annotate the cells with the formatted values
#     351 if self.annot:
# --> 352     self._annotate_heatmap(ax, mesh)
#
# File c:\Users\brend\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\matrix.py:263, in _HeatMapper._annotate_heatmap(self, ax, mesh)
#     261 text_kwargs = dict(color=text_color, ha="center", va="center")
#     262 text_kwargs.update(self.annot_kws)
# --> 263 ax.text(x, y, annotation, **text_kwargs)
#
# File c:\Users\brend\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\axes\_axes.py:702, in Axes.text(self, x, y, s, fontdict, **kwargs)
#     700 t = mtext.Text(x, y, text=s, **effective_kwargs)
#     701 if t.get_clip_path() is None:
# --> 702     t.set_clip_path(self.patch)
#     703 self._add_text(t)
#     704 return t
#
# File c:\Users\brend\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\text.py:593, in Text.set_clip_path(self, path, transform)
#     591 def set_clip_path(self, path, transform=None):
#     592     # docstring inherited.
# --> 593     super().set_clip_path(path, transform)
#     594     self._update_clip_properties()
#
# File c:\Users\brend\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\artist.py:802, in Artist.set_clip_path(self, path, transform)
#     800 if transform is None:
#     801     if isinstance(path, Rectangle):
# --> 802         self.clipbox = TransformedBbox(Bbox.unit(),
#     803                                        path.get_transform())
#     804         self._clippath = None
#     805         success = True
#
# File c:\Users\brend\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\transforms.py:797, in Bbox.unit()
#     794 @staticmethod
#     795 def unit():
#     796     """Create a new unit `Bbox` from (0, 0) to (1, 1)."""
# --> 797     return Bbox([[0, 0], [1, 1]])
#
# File c:\Users\brend\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\transforms.py:771, in Bbox.__init__(self, points, **kwargs)
#     768     raise ValueError('Bbox points must be of the form '
#     769                      '"[[x0, y0], [x1, y1]]".')
#     770 self._points = points
# --> 771 self._minpos = _default_minpos.copy()
#     772 self._ignore = True
#     773 # it is helpful in some contexts to know if the bbox is a
#     774 # default or has been mutated; we store the orig points to
#     775 # support the mutated methods
#
# KeyboardInterrupt:
